# %%
import pandas as pd

# %%
df = pd.read_csv("realestate.csv")

# %%
df.shape
# Out:
# (49, 4)

# %%
list(df.columns)
# Out:
# ['jobs_type', 'title', 'jobs_text', 'URLs']

# %%
df["jobs_type"].value_counts()
# Out:
# data     25
# tools    19
# leads     5
# Name: jobs_type, dtype: int64

# %%
leads = df[df["jobs_type"] == "leads"]
tools = df[df["jobs_type"] == "tools"]
data = df[df["jobs_type"] == "data"]

# %%
# Jobs text

count = 0
jobs = list(leads["jobs_text"])

for job in jobs:
    count += 1
    print(f"                                                      {count}")
    print()
    print(job)
    print()
    print()

    print("*********************************************************")
# Out:
#                                                       1
#
# "We are looking to generate leads on the Canadian real estate market. As part of the lead generation process, we are looking to scrape recent sales data from a website. Information that we will require will include, but is not limited to:
#
# - Address
# - Most recent transaction date
# - Transaction sales price
# - Current estimated home value
#
# For this specific site, the complexities include:
#
# - You need to be logged in to the site
# - You need to navigate to the page by inputting the address
# - You need to capture data from specific sections on the site
#
# We are looking for someone who has worked with and/or created various web scraping tools to generate this data, and are familiar with processes for deduplicating and cleansing lead lists."
#
#
# *********************************************************
#                                                       2
#
# "Hi, I would like someone to extract/scrape the emails of all the real estate brokers who have listings on this website: (link removed)
#
# I need an excel or CSV with the broker's 1. first name, 2. last name, and 3. email address."
#
#
# *********************************************************
#                                                       3
#
# "Hi, I would like someone to extract/scrape the emails of all the real estate brokers who have listings on this website: (link removed)
#
# I need an excel or CSV with the broker's 1. first name, 2. last name, and 3. email address."
#
#
# *********************************************************
#                                                       4
#
# "I’m looking for a list of of multi unit properties that are off market in two cities in two different states. I would like: address, property type, owner address, phone number and email."
#
#
# *********************************************************
#                                                       5
#
# "I need someone to scrape real estate agents emails from Zillow. I will need Realtor Name, Realtor Email Address, Mailing Address, Realtor Phone Number, and the URL of the individual listing attached to the realtor. The results need to be provided in csv format. . I will provide the search areas."
#
#
# *********************************************************
